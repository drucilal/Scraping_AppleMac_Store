# %% [markdown]
# # Explanatory Data Analysis on Apple Mac App Store
# ### Which type of profession will be benefit more from this app store?
# Graphics & Design, Education, Business, Music, Video, Photography, Medical
# How could these apps benefit individuals who are apart of these fields?

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from tabulate import tabulate
from mac import *
from var import *
# Out:
# /Users/drucila/Desktop/mac_store/var.py:179: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## How many apps are in each category?

# %% [markdown]
# #### Let's get an brief idea of each genre at the store

# %%
category_plot('category', mac_apps, 'cool', 'Category')

# %% [markdown]
# ### Findings:
# #####  Most of the apps in the app store are educational.

# %% [markdown]
# ## Size

# %% [markdown]
# #### Group the dataset by size to visaulize the smallest to largest apps
# GB: gigabytes (largest),
# MB: megabytes ,
# KB: kilobytes (smallest),

# %% [markdown]
# #### Grouping by SIze

# %% [markdown]
# Large Apps : GB

# %%
large = mac_apps[mac_apps['size'].str.contains('GB')]
large_size = large[['category','name','size', 'price', 'total_languages']].sort_values(by='size', ascending = False)
large_size['size'] = large_size['size'].str.replace('GB', '')
large_size['size'] = large_size['size'].astype(float)

# %% [markdown]
# Apps : MB

# %%
medium = mac_apps[mac_apps['size'].str.contains('MB')]
medium_size = medium[['category','name','size', 'price', 'total_languages']].sort_values(by='size', ascending = False)
medium_size['size'] = medium_size['size'].str.replace('MB', '')
medium_size['size'] = medium_size['size'].astype(float)

# %% [markdown]
# Smallest Apps : KB

# %%
small = mac_apps[mac_apps['size'].str.contains('KB')]
small_size = small[['category','name','size', 'price', 'total_languages']].sort_values(by='size', ascending = False)
small_size['size'] = small_size['size'].str.replace('KB', '')
small_size['size'] = small_size['size'].astype(float)

# %% [markdown]
# ## Which genre contains the largest size of apps?

# %%
add_plot(large_size,'category', 'size', 'darkblue')

# %% [markdown]
# Findings:
#  We can see that the graphic design contains the largest size of apps.
#  Let's continue to explore the following seven categories.

# %% [markdown]
# ### Graphics & Design

# %%
apps_plot(largest_graphics, 'size', 'name', 'darkblue')

# %% [markdown]
# Findings: Textpro:
#
# This app is known to be a perfect fit for graphic designers. It allows them to easily transform text designs by providing them with over 5,0000 text design templates.

# %% [markdown]
# ### Music

# %%
apps_plot(largest_music, 'size', 'name', 'darkblue')

# %% [markdown]
# Findings: RnB
#
# A helpful tool for music producers in which they are provided with high quality R and B hit sounds that will expedite their work.

# %% [markdown]
# ### Education

# %%
apps_plot(largest_education, 'size', 'name', 'darkblue')

# %% [markdown]
# Findings:
# Learn Spanish - Complete Audio Course:
# Given that majority of schools have imported the Spanish langugage into their curriculum, this app can be an additonal learning resource to help students master this subject.

# %% [markdown]
# ### Business

# %%
apps_plot(largest_business, 'size', 'name', 'darkblue')

# %% [markdown]
# Findings : Templates Hero Designs for MS Office:
#
# This app provides Microsoft Word users with various types of templates used for both personal and business use.

# %% [markdown]
# ### Video

# %%
apps_plot(largest_video, 'size', 'name', 'darkblue')

# %% [markdown]
# Findings: Learn- Final Cut Pro X 10.1:
#
# Edition contains of the most memory in the business category. This app is generally used for editing videos.

# %% [markdown]
# ### Photography

# %%
apps_plot(largest_photo, 'size', 'name', 'darkblue')

# %% [markdown]
# Findings: Adobe Photoshop Elements 2019:
#
# This popular software is generally used for editing photos.

# %% [markdown]
# ### Medical

# %%
apps_plot(largest_medical, 'size', 'name', 'darkblue')

# %% [markdown]
# Findings: Medical School
#
# This app is beneficial for students in the medical field who are seeking an additional learning tool.

# %% [markdown]
# ## Looking at Apps with the highest megabytes (MB)

# %%
mac.add_plot(medium_size, 'category', 'size', 'darkred')

# %% [markdown]
# Findings : We can see that the music  contains the highest number of MB.
#
# Let's look deeper into our categories of interests.

# %% [markdown]
# ### Graphic & Design

# %%
mac.apps_plot(medium_graphics, 'size', 'name', 'darkred')

# %% [markdown]
# Findings: Flyer Lab - Template for Pages
#
# This app provides users with various forms of flyer templates to choose from.

# %% [markdown]
# ## Music

# %%
mac.apps_plot(medium_music, 'size', 'name', 'darkred' )

# %% [markdown]
# Findings: Ignite
#
# Similar to RnB, it gives musicans or producers a great starting point in their work.

# %% [markdown]
# ## Education

# %%
mac.apps_plot(medium_education, 'size', 'name', 'darkred')

# %% [markdown]
# Findings: Professor Teaches for Excel
#
# This app is for learners interested in learning useful tools in Microsoft Excel.

# %% [markdown]
# ### Business

# %%
mac.apps_plot(medium_business, 'size', 'name', 'darkred')

# %% [markdown]
# Findings: Professor Teaches for Excel
#
# This app is for learners interested in learning useful tools in Microsoft Excel.

# %% [markdown]
# ### Video

# %%
mac.apps_plot(medium_video, 'size', 'name', 'darkred')

# %% [markdown]
# ### Photography

# %%
mac.apps_plot(medium_photo, 'size', 'name', 'darkred')

# %% [markdown]
# ### Medical

# %%
mac.apps_plot(medium_medical, 'size', 'name', 'darkred')

# %% [markdown]
# ## Let's Look at the smallest apps (KB)

# %%
mac.add_plot(small_size, 'category', 'size', '#539ecd' )

# %% [markdown]
# Findings: Here we can visualize that business, utilities, and music are the top three highest small apps.

# %% [markdown]
# ### Graphic & Design

# %%
mac.apps_plot(small_graphics, 'size', 'name', '#539ecd')

# %% [markdown]
# ### Education

# %%
mac.apps_plot(small_education, 'size', 'name', '#539ecd')

# %% [markdown]
# ### Business

# %%
mac.apps_plot(small_business, 'size', 'name', '#539ecd')

# %% [markdown]
# Findings: Credit Card Terminal - Accept Payment with Model Point of Sale Reader
#
# This can be a useful tool for businesses who are interested in accepting credit card payments through their laptop.

# %% [markdown]
# ### Video

# %%
mac.apps_plot(small_video, 'size', 'name', '#539ecd')

# %% [markdown]
# ### Music

# %% [markdown]
# Findings: IPv4Calc has the highest number of KB in Utilities. This tool is for network operators and students that allows them to extract information from an IP address.

# %%
mac.apps_plot(small_music, 'size', 'name', '#539ecd')

# %% [markdown]
# Findings: Radios de Argentina has the highest number of KB.

# %% [markdown]
# ### Photography

# %%
mac.apps_plot(small_photo, 'size', 'name', '#539ecd')

# %% [markdown]
# ### Medical

# %%
mac.apps_plot(small_medical, 'size', 'name', '#539ecd')

# %% [markdown]
# We have looked at the size and visualized which genre and apps that contained the most memory in each memory category.
#
# Given that graphic apps contained the most memory, could it be the most expensive category as well?
#
#
# First,  let's look and visualize free and paid apps.

# %%
mac.apps_plot(price_c, 'price_category', 'count', 'darkblue')

# %% [markdown]
# Findings : Majority of apps in the mac store are paid. To continue to answer our question, let's look paid apps in each category

# %%
mac.category_plot('category', paid, 'Blues_d', 'Category')

# %% [markdown]
# Findings:
#
# Majority of paid apps are from the graphics and design category. Given that graphics and design apps had the highest number of large sized apps, it would make sense that majority of the apps were paid.

# %% [markdown]
# ## Total Price

# %%
mac.add_plot(paid, 'category', 'price', '#34495e')

# %% [markdown]
# Findings: Again we see that the most expensive apps are Graphics & Design apps.
# Lets' dig into this genre and visualize the most expensive apps.

# %%
mac.apps_plot(paid_graph, 'price', 'name', '#34495e')

# %% [markdown]
# Findings: Shark Cad is the most expensive graphics and design apps ($700). This app consists of various graphic programs and features that enable users to work more efficiently.

# %% [markdown]
# For the affect on price vs memory size, we saw how graphic apps consisted of the most memory and was the most expensive.

# %% [markdown]
# ## Let's Look at the Free Apps

# %%
mac.category_plot('category', free, 'Blues_d', 'Category')

# %% [markdown]
# Findings : Majority of education apps are free. Fortunately, students are exposed to free learning resources that can help them with their course work.

# %% [markdown]
# ### Now that we have looked the prices and memory size, the rating is also essential in deciding what types of apps are worth to buy and download.

# %% [markdown]
# ## Ratings

# %% [markdown]
# Average rating in each category

# %%
mac.avg_plot(filtered_rating, 'category', 'rating_est', 'darkblue')

# %% [markdown]
# Findings: Weather and Sports are the top two apps that are highly rated.
#
# Given that the objective of this EDA is to help buyers view which app would be essential for their occupation.
#
# We will dig a little deeper into six professions ( music, education, medical, entertainment, photography, video, graphics and design, and business) and visualize the top 10 highest rated apps in each of the categories.

# %% [markdown]
# ### Education Rating

# %%
rating_plot(education_rate)

# %% [markdown]
# #### Top 10 Education Ratings

# %%
(highest_education_rate1.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_bb7d65e6_0c00_11ea_9077_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_bb7d65e6_0c00_11ea_9077_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.6  </td>
#                         <td id="T_bb7d65e6_0c00_11ea_9077_784f436faa1arow0_col1" class="data row0 col1" >Human Resources SPHR Exam Prep</td>
#             </tr>
#             <tr>
#                                 <td id="T_bb7d65e6_0c00_11ea_9077_784f436faa1arow1_col0" class="data row1 col0" > OS X 10.6.6 </td>
#                         <td id="T_bb7d65e6_0c00_11ea_9077_784f436faa1arow1_col1" class="data row1 col1" >States of Germany</td>
#             </tr>
#             <tr>
# ...

# %%
table_style(highest_education_rate)
# Out:
# <style  type="text/css" >
#     #T_0723ae90_0c03_11ea_8a52_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_0723ae90_0c03_11ea_8a52_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_0723ae90_0c03_11ea_8a52_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_0723ae90_0c03_11ea_8a52_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_0723ae90_0c03_11ea_8a52_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0723ae90_0c03_11ea_8a52_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.6  </td>
#                         <td id="T_0723ae90_0c03_11ea_8a52_784f436faa1arow0_col1" class="data row0 col1" >Human Resources SPHR Exam Prep</td>
# ...

# %%
(medium_education_rate.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_c0a84dc4_0c00_11ea_9077_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c0a84dc4_0c00_11ea_9077_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.6  </td>
#                         <td id="T_c0a84dc4_0c00_11ea_9077_784f436faa1arow0_col1" class="data row0 col1" >Math-for-Kids</td>
#                         <td id="T_c0a84dc4_0c00_11ea_9077_784f436faa1arow0_col2" class="data row0 col2" >4.5</td>
#             </tr>
#             <tr>
#                                 <td id="T_c0a84dc4_0c00_11ea_9077_784f436faa1arow1_col0" class="data row1 col0" > OS X 10.6  </td>
#                         <td id="T_c0a84dc4_0c00_11ea_9077_784f436faa1arow1_col1" class="data row1 col1" >ScalePhobia</td>
# ...

# %% [markdown]
# ####  Education Ratings in the range of (3.0 - 4.5)

# %%
table_style(medium_education_rate1)
# Out:
# <style  type="text/css" >
#     #T_db59db68_0c02_11ea_8a52_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_db59db68_0c02_11ea_8a52_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_db59db68_0c02_11ea_8a52_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_db59db68_0c02_11ea_8a52_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_db59db68_0c02_11ea_8a52_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_db59db68_0c02_11ea_8a52_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.6  </td>
# ...

# %% [markdown]
# ### Music Ratings

# %%
rating_plot(music_rate)

# %% [markdown]
# ### Top 10 Music Ratings

# %%
(highest_music1.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_3e945aaa_0c03_11ea_8a52_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_3e945aaa_0c03_11ea_8a52_784f436faa1arow0_col0" class="data row0 col0" > OS 10.12  </td>
#                         <td id="T_3e945aaa_0c03_11ea_8a52_784f436faa1arow0_col1" class="data row0 col1" >RadioBrowser</td>
#             </tr>
#             <tr>
#                                 <td id="T_3e945aaa_0c03_11ea_8a52_784f436faa1arow1_col0" class="data row1 col0" > OS X 10.7  </td>
#                         <td id="T_3e945aaa_0c03_11ea_8a52_784f436faa1arow1_col1" class="data row1 col1" >Cactus Music</td>
#             </tr>
#             <tr>
#                                 <td id="T_3e945aaa_0c03_11ea_8a52_784f436faa1arow2_col0" class="data row2 col0" > OS X 10.7  </td>
# ...

# %%
table_style(highest_music)
# Out:
# <style  type="text/css" >
#     #T_4ccceeb6_0c03_11ea_8a52_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_4ccceeb6_0c03_11ea_8a52_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_4ccceeb6_0c03_11ea_8a52_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_4ccceeb6_0c03_11ea_8a52_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_4ccceeb6_0c03_11ea_8a52_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_4ccceeb6_0c03_11ea_8a52_784f436faa1arow0_col0" class="data row0 col0" > OS 10.12  </td>
#                         <td id="T_4ccceeb6_0c03_11ea_8a52_784f436faa1arow0_col1" class="data row0 col1" >RadioBrowser</td>
#             </tr>
# ...

# %% [markdown]
# ####  Music Ratings in the range of (3.0 - 4.5)

# %%
table_style(medium_music_rate1)
# Out:
# <style  type="text/css" >
#     #T_61c095ac_0c03_11ea_8a52_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_61c095ac_0c03_11ea_8a52_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_61c095ac_0c03_11ea_8a52_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_61c095ac_0c03_11ea_8a52_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_61c095ac_0c03_11ea_8a52_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_61c095ac_0c03_11ea_8a52_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.6.6  </td>
# ...

# %%
table_style(medium_music_rate)
# Out:
# <style  type="text/css" >
#     #T_11ad82ea_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_11ad82ea_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_11ad82ea_0c09_11ea_9b35_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_11ad82ea_0c09_11ea_9b35_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_11ad82ea_0c09_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_11ad82ea_0c09_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.6.6  </td>
# ...

# %% [markdown]
# ### Business Ratings

# %%
rating_plot(business_rate)

# %% [markdown]
# #### Top 10  Business Ratings

# %%
table_style(highest_business1)
# Out:
# <style  type="text/css" >
#     #T_764d5f5e_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_764d5f5e_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_764d5f5e_0c09_11ea_9b35_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_764d5f5e_0c09_11ea_9b35_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_764d5f5e_0c09_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_764d5f5e_0c09_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.9  </td>
#                         <td id="T_764d5f5e_0c09_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >Word Count Popup</td>
#             </tr>
# ...

# %%
(highest_business.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_2add4d78_0c08_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2add4d78_0c08_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.9  </td>
#                         <td id="T_2add4d78_0c08_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >Word Count Popup</td>
#             </tr>
#             <tr>
#                                 <td id="T_2add4d78_0c08_11ea_9b35_784f436faa1arow1_col0" class="data row1 col0" > OS 10.12  </td>
#                         <td id="T_2add4d78_0c08_11ea_9b35_784f436faa1arow1_col1" class="data row1 col1" >Tunnel - Workspace ONE</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# #### Business Ratings in the range of (3.0 - 4.5)

# %%
table_style(medium_business_rate1)
# Out:
# <style  type="text/css" >
#     #T_83f5658e_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_83f5658e_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_83f5658e_0c09_11ea_9b35_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_83f5658e_0c09_11ea_9b35_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_83f5658e_0c09_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_83f5658e_0c09_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.6  </td>
# ...

# %%
(medium_business_rate.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_2b81e25c_0c08_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2b81e25c_0c08_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.6  </td>
#                         <td id="T_2b81e25c_0c08_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >TikiToki Desktop</td>
#                         <td id="T_2b81e25c_0c08_11ea_9b35_784f436faa1arow0_col2" class="data row0 col2" >4.5</td>
#             </tr>
#             <tr>
#                                 <td id="T_2b81e25c_0c08_11ea_9b35_784f436faa1arow1_col0" class="data row1 col0" > OS X 10.9.0  </td>
# ...

# %% [markdown]
# ### Video Ratings

# %%
rating_plot(video_rate)

# %% [markdown]
# #### Top Ten Video Ratings

# %%
table_style(highest_video1)
# Out:
# <style  type="text/css" >
#     #T_406fcc1e_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_406fcc1e_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_406fcc1e_0c09_11ea_9b35_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_406fcc1e_0c09_11ea_9b35_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_406fcc1e_0c09_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_406fcc1e_0c09_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.7  </td>
#                         <td id="T_406fcc1e_0c09_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >Media Menu Lite - Movie Edition</td>
# ...

# %%
(highest_video.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_2c300e90_0c08_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2c300e90_0c08_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.7  </td>
#                         <td id="T_2c300e90_0c08_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >Media Menu Lite - Movie Edition</td>
#             </tr>
#             <tr>
#                                 <td id="T_2c300e90_0c08_11ea_9b35_784f436faa1arow1_col0" class="data row1 col0" > OS X 10.7  </td>
#                         <td id="T_2c300e90_0c08_11ea_9b35_784f436faa1arow1_col1" class="data row1 col1" >Final Converter</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# #### Video Ratings in the range of (3.0 - 4.5)

# %%
table_style(medium_video_rate1)
# Out:
# <style  type="text/css" >
#     #T_90a281fe_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_90a281fe_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_90a281fe_0c09_11ea_9b35_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_90a281fe_0c09_11ea_9b35_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_90a281fe_0c09_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_90a281fe_0c09_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.7  </td>
# ...

# %%
(medium_video_rate.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_2c9d8268_0c08_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2c9d8268_0c08_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.7  </td>
#                         <td id="T_2c9d8268_0c08_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >Super Video Converter Pro</td>
#                         <td id="T_2c9d8268_0c08_11ea_9b35_784f436faa1arow0_col2" class="data row0 col2" >4.5</td>
#             </tr>
#             <tr>
#                                 <td id="T_2c9d8268_0c08_11ea_9b35_784f436faa1arow1_col0" class="data row1 col0" > OS X 10.6.6 </td>
# ...

# %% [markdown]
# ### Photography Ratings

# %%
rating_plot(photo_rate)

# %% [markdown]
# ### Top 10 Photography Ratings

# %%
table_style(highest_photo1)
# Out:
# <style  type="text/css" >
#     #T_adc645cc_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_adc645cc_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_adc645cc_0c09_11ea_9b35_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_adc645cc_0c09_11ea_9b35_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_adc645cc_0c09_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_adc645cc_0c09_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.11  </td>
#                         <td id="T_adc645cc_0c09_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >HighDR Photos Extension</td>
# ...

# %%
(highest_photo.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_2d4a6758_0c08_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2d4a6758_0c08_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.11  </td>
#                         <td id="T_2d4a6758_0c08_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >HighDR Photos Extension</td>
#             </tr>
#             <tr>
#                                 <td id="T_2d4a6758_0c08_11ea_9b35_784f436faa1arow1_col0" class="data row1 col0" > OS X 10.9  </td>
#                         <td id="T_2d4a6758_0c08_11ea_9b35_784f436faa1arow1_col1" class="data row1 col1" >Photo & Video HDR</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ### Photography Ratings in the range of (3.0 - 4.5)

# %%
table_style(medium_photo_rate1)
# Out:
# <style  type="text/css" >
#     #T_bd9bc058_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_bd9bc058_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_bd9bc058_0c09_11ea_9b35_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_bd9bc058_0c09_11ea_9b35_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_bd9bc058_0c09_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_bd9bc058_0c09_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.8.0  </td>
# ...

# %%
(medium_photo_rate.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_40afb136_0c08_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_40afb136_0c08_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.8.0  </td>
#                         <td id="T_40afb136_0c08_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >QuickScale</td>
#                         <td id="T_40afb136_0c08_11ea_9b35_784f436faa1arow0_col2" class="data row0 col2" >4.5</td>
#             </tr>
#             <tr>
#                                 <td id="T_40afb136_0c08_11ea_9b35_784f436faa1arow1_col0" class="data row1 col0" > OS 10.13  </td>
#                         <td id="T_40afb136_0c08_11ea_9b35_784f436faa1arow1_col1" class="data row1 col1" >RAW Power</td>
# ...

# %% [markdown]
# ### Medical Rating

# %%
rating_plot(medicine_rate)

# %% [markdown]
# ### Top 10 Medical Rating

# %%
table_style(highest_med1)
# Out:
# <style  type="text/css" >
#     #T_f00022e6_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_f00022e6_0c09_11ea_9b35_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_f00022e6_0c09_11ea_9b35_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_f00022e6_0c09_11ea_9b35_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_f00022e6_0c09_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_f00022e6_0c09_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.11  </td>
#                         <td id="T_f00022e6_0c09_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >ACP Board Study Guide</td>
# ...

# %%
h = highest_med.head(20)
(h.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_2c1654a8_0c0a_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2c1654a8_0c0a_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.11  </td>
#                         <td id="T_2c1654a8_0c0a_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >ACP Board Study Guide</td>
#             </tr>
#             <tr>
#                                 <td id="T_2c1654a8_0c0a_11ea_9b35_784f436faa1arow1_col0" class="data row1 col0" > OS X 10.10  </td>
#                         <td id="T_2c1654a8_0c0a_11ea_9b35_784f436faa1arow1_col1" class="data row1 col1" >Rendia Favorites</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# #### Medical Rating in the range of (3.0 - 4.5)

# %%
table_style(medium_med_rate1)
# Out:
# <style  type="text/css" >
#     #T_0dd36b48_0c0a_11ea_9b35_784f436faa1a tr:nth-of-type(odd) {
#           background: #eee;
#     }    #T_0dd36b48_0c0a_11ea_9b35_784f436faa1a tr:nth-of-type(even) {
#           background: white;
#     }    #T_0dd36b48_0c0a_11ea_9b35_784f436faa1a th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_0dd36b48_0c0a_11ea_9b35_784f436faa1a td {
#           font-family: verdana;
#     }</style><table id="T_0dd36b48_0c0a_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0dd36b48_0c0a_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.8  </td>
# ...

# %%
m = medium_med_rate.head(20)
(m.style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_1b813572_0c0a_11ea_9b35_784f436faa1a" ><thead>    <tr>        <th class="col_heading level0 col0" >Compatibility</th>        <th class="col_heading level0 col1" >Name</th>        <th class="col_heading level0 col2" >Rating</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_1b813572_0c0a_11ea_9b35_784f436faa1arow0_col0" class="data row0 col0" > OS X 10.8  </td>
#                         <td id="T_1b813572_0c0a_11ea_9b35_784f436faa1arow0_col1" class="data row0 col1" >Elbow Pro III</td>
#                         <td id="T_1b813572_0c0a_11ea_9b35_784f436faa1arow0_col2" class="data row0 col2" >4.5</td>
#             </tr>
#             <tr>
#                                 <td id="T_1b813572_0c0a_11ea_9b35_784f436faa1arow1_col0" class="data row1 col0" > OS 10.12  </td>
# ...
